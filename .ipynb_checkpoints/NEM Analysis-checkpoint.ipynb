# %% [markdown]
# # Add title here
#
# * asdsa
# * asdasdf
# * dfg

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np

import ipywidgets as widgets
from ipywidgets import interact

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

from statsmodels.tsa.seasonal import seasonal_decompose

import nemdata

import sqlite3

# %% [markdown]
# ## Select Region and Date Range

# %%
drop_region = widgets.Dropdown(options=['NSW1', 'TAS1', 'SA1', 'QLD1', 'VIC1'],description='State:',disabled=False,index=4)

button = widgets.Button(description="Select")

def on_button_clicked(b):
    global region
    region = drop_region.value
    print(f"The selected region is: {region}")

button.on_click(on_button_clicked)

display(drop_region)
display(button)
# Out:
# Dropdown(description='State:', index=4, options=('NSW1', 'TAS1', 'SA1', 'QLD1', 'VIC1'), value='VIC1')
# Button(description='Select', style=ButtonStyle())

# %% [markdown]
# ## Import Data

# %%
#Uncomment below if first time, after the first download the data is stored in a database

# data = nemdata.download(start="2020-01", end="2024-01", table="trading-price")
# data = nemdata.load()['trading-price']

# data_region = data.loc[data.REGIONID==region,['interval-start',
#        'RRP',
#        'RAISE6SECRRP', 'RAISE60SECRRP','RAISE5MINRRP', 'RAISEREGRRP',
#        'LOWER6SECRRP', 'LOWER60SECRRP','LOWER5MINRRP', 'LOWERREGRRP']]
# data_region.set_index('interval-start',inplace=True)
# data_region.sort_index(ascending=True,inplace=True)
# data_region.index = data_region.index.tz_localize(None)
# data_region.reset_index(inplace=True)
# data_region.rename(columns={'interval-start':'SETTLEMENTDATE'},inplace=True)

# #Create a connection to the data base and initiate a cursor
# conn = sqlite3.connect("NEM_historical.db")
# cur = conn.cursor()

# #Create the table if it dosen't exist
# cur.execute("""CREATE TABLE IF NOT EXISTS nem_data(
#                     SETTLEMENTDATE TEXT,
#                     RRP REAL,
#                     RAISE6SECRRP REAL, 
#                     RAISE60SECRRP REAL,
#                     RAISE5MINRRP REAL, 
#                     RAISEREGRRP REAL,
#                     LOWER6SECRRP REAL, 
#                     LOWER60SECRRP REAL,
#                     LOWER5MINRRP REAL, 
#                     LOWERREGRRP REAL
#                     )""")
# conn.commit()

# #Add the data_region to the dataframe by appending it
# data_region.to_sql('nem_data', conn, if_exists='append', index=False)
# #Check the data base table and if duplicates exists remove them from the data base
# conn.execute("""DELETE FROM nem_data
# WHERE rowid NOT IN (
#     SELECT MIN(rowid)
#     FROM nem_data
#     GROUP BY SETTLEMENTDATE, RRP, RAISE6SECRRP, RAISE60SECRRP, RAISE5MINRRP, RAISEREGRRP, LOWER6SECRRP, LOWER60SECRRP, LOWER5MINRRP, LOWERREGRRP)
#     """)
# conn.commit()

# %%
#Create a connection to the data base and initiate a cursor
conn = sqlite3.connect("NEM_historical.db")
cur = conn.cursor()

#Select all the rows where the product is cap
NEM_ALL_DATA = cur.execute("""SELECT * 
                        FROM nem_data
                        """)
conn.commit()
NEM_ALL_DATA = pd.DataFrame(NEM_ALL_DATA.fetchall(),columns=['SETTLEMENTDATE', 'RRP', 'RAISE6SECRRP', 'RAISE60SECRRP', 'RAISE5MINRRP', 'RAISEREGRRP', 'LOWER6SECRRP', 'LOWER60SECRRP', 'LOWER5MINRRP', 'LOWERREGRRP'])

# %%
NEM_ALL_DATA.SETTLEMENTDATE = pd.to_datetime(NEM_ALL_DATA.SETTLEMENTDATE)
NEM_ALL_DATA.set_index('SETTLEMENTDATE',inplace=True)

# %%
NEM_ALL_DATA.head()
# Out:
#                        RRP  RAISE6SECRRP  RAISE60SECRRP  RAISE5MINRRP  \
# SETTLEMENTDATE
# 2020-01-01 00:00:00  64.76          1.75           2.47          0.73
# 2020-01-01 00:05:00  64.76          1.75           2.47          0.73
# 2020-01-01 00:10:00  64.76          1.75           2.47          0.73
# 2020-01-01 00:15:00  64.76          1.75           2.47          0.73
# 2020-01-01 00:20:00  64.76          1.75           2.47          0.73
#
#                      RAISEREGRRP  LOWER6SECRRP  LOWER60SECRRP  LOWER5MINRRP  \
# SETTLEMENTDATE
# 2020-01-01 00:00:00        19.24          0.05           0.38          0.44
# 2020-01-01 00:05:00        19.24          0.05           0.38          0.44
# 2020-01-01 00:10:00        19.24          0.05           0.38          0.44
# 2020-01-01 00:15:00        19.24          0.05           0.38          0.44
# 2020-01-01 00:20:00        19.24          0.05           0.38          0.44
#
#                      LOWERREGRRP
# SETTLEMENTDATE
# 2020-01-01 00:00:00        15.68
# 2020-01-01 00:05:00        15.68
# 2020-01-01 00:10:00        15.68
# 2020-01-01 00:15:00        15.68
# 2020-01-01 00:20:00        15.68

# %%
daily_average = NEM_ALL_DATA.groupby(NEM_ALL_DATA.index.time)[['RRP']].mean()

fig, ax = plt.subplots(figsize=(20,8))
daily_average.plot(ax=ax,color='green',linewidth=3)
plt.title('Daily Average Price', alpha=0.9, weight="bold", fontsize=20, loc="left", pad=10,color="green")
plt.ylabel("Spot Price ($/MWh)",fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel("Time",fontsize=15)
plt.xticks(fontsize=15)
plt.xticks(ticks=range(0,86400,1800),labels=range(0,2400,50),rotation=60)
plt.xlim((0,86400))
plt.show()

# %%
data_region_decom = data_region[['RRP']]
# Decompose the data
decomposition = seasonal_decompose(data_region_decom,period=12)

# Extract componets
trend = decomposition.trend
seasonal = decomposition.seasonal
remainder = decomposition.resid
original = data_region['RRP']

# Create a figure with 4 subplots (original on top, others stacked below)
fig, axes = plt.subplots(4, 1, figsize=(20, 12), gridspec_kw={'hspace': 0.4})  # Adjust figsize as needed

# Plot original on top subplot
axes[0].plot(original, color='red', label='Original Load')
axes[0].set(ylabel='Load (kw)', title='Original Load')

# Plot remaining components on stacked subplots
axes[1].plot(trend, color='blue', label='Trend')
axes[1].set(ylabel='Load (kw)', title='Trend')
axes[2].plot(seasonal, color='green', label='Seasonal')
axes[2].set(ylabel='Load (kw)', title='Seasonal')
axes[3].plot(remainder, color='orange', label='Remainder')
axes[3].set(ylabel='Load (kw)', title='Remainder')

# Rotate x-axis labels for bottom subplot
plt.setp(axes[-1].xaxis.get_majorticklabels(), rotation=45)

plt.tight_layout()  # Adjust spacing between subplots
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data_region_decom = data_region[['RRP']]
#       2 # Decompose the data
#       3 decomposition = seasonal_decompose(data_region_decom,period=12)
#
# NameError: name 'data_region' is not defined
